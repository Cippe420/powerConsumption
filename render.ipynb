# %%
import serial
import matplotlib.pyplot as plt
import numpy as np

with open('currentMeasure.csv','r') as f:
    data = f.readlines()

data = [x.strip() for x in data]

#print(data)

amps = []
watts = [0 for i in range(100)]

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ylim([0,20])
plt.xlim([0,100])

line, =ax.plot(watts)

ax.set_title('Power Consumption')
ax.set_xlabel('Time')
ax.set_ylabel('Power (W)')

index = 0 

while True:

    new_value = data[index%17].split()[3][1::]
    index += 1
    watts.append(float(new_value))
    if len(watts) > 100:
        watts = watts[-100:]

    line.set_ydata(watts)
    line.set_xdata(np.arange(len(watts)))
    plt.draw()
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 40
#      38 line.set_xdata(np.arange(len(watts)))
#      39 plt.draw()
# ---> 40 plt.pause(0.1)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:663, in pause(interval)
#     661         canvas.draw_idle()
#     662     show(block=False)
# --> 663     canvas.start_event_loop(interval)
#     664 else:
#     665     time.sleep(interval)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:2381, in FigureCanvasBase.start_event_loop(self, timeout)
#    2379 while self._looping and counter * timestep < timeout:
#    2380     self.flush_events()
# -> 2381     time.sleep(timestep)
#    2382     counter += 1
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
import serial
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display,clear_output


data= np.random.randint(0,1023,size=(50,))

plt.ion()
fig, ax = plt.subplots()
line, = ax.plot(data,label = 'Data')

ax.set_xlim(0,100)
ax.set_ylim(0,1023)
ax.set_title('Real Time Data Plot')
ax.set_xlabel('Time')
ax.set_ylabel('Data')
ax.legend(['Data'],loc='upper right')

while True:

    new_data = np.random.randint(0,1023)
    data = np.append(data,new_data)[-100:]

    line.set_ydata(data)
    line.set_xdata(np.arange(len(data)))

    ax.set_xlim(0,len(data))

    fig.canvas.draw()
    fig.canvas.flush_events()
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 33
#      31 fig.canvas.draw()
#      32 fig.canvas.flush_events()
# ---> 33 plt.pause(0.1)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:665, in pause(interval)
#     663     canvas.start_event_loop(interval)
#     664 else:
# --> 665     time.sleep(interval)
#
# KeyboardInterrupt:
